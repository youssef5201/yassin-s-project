# %%
import pandas as pd
l = [{'name' : 'yassin' ,'age' : 13,'salary ': 10000 ,'start ':2022 }
     ]
DF = pd.DataFrame(l)
print(DF)
# Out:
#      name  age  salary   start
# 0  yassin   13    10000    2022
